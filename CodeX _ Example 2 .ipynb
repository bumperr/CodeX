# %% [markdown]
# Simple basic linear regression

# %%
import numpy as np
import pandas as pd
import seaborn   as sns
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
advertising_dataset=pd.read_csv("tvmarketing.csv") #upload first file

# %%
advertising_dataset.head(10)

# %%
advertising_dataset.isnull().sum()

# %%
advertising_dataset.describe()

# %%
correlation_matrix = advertising_dataset.corr()

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
print(f"Info:{advertising_dataset.info()} ,\n\nShape:{advertising_dataset.shape}")

# %%
from matplotlib import pyplot as plt
plt.scatter(advertising_dataset['TV'],advertising_dataset["Sales"])
plt.title('TV vs Sales ')
plt.xlabel("Tv")
plt.ylabel('Sale')
plt.show()

# %% [markdown]
# Preparing X and Y values

# %%
# Putting feature variable to X
X = advertising_dataset['TV']
## Reshape 'X' to a 2D array
X = X.values.reshape(-1, 1)

# Putting response variable to y
y = advertising_dataset['Sales']
## Reshape 'y' to a 2D array
y= y.values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160, 1)
# (40, 1)

# %% [markdown]
# Equation of linear regression
# y=c+m1x1+m2x2+...+mnxn
#
# y
#   is the response
# c
#   is the intercept
# m1
#   is the coefficient for the first feature
# mn
#   is the coefficient for the nth feature
# In our case:
#
# y=c+m1×TV
#
# The  m
#   values are called the model coefficients or model parameters.

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train) # Training the algorithm

# %%
c = round(regressor.intercept_[0], 2)
m = round(regressor.coef_[0][0], 2)

# Format the equation with two decimal places
equation = f"y = {m}x + {c}"

print(equation)
# Out:
# y = 0.05x + 7.29

# %%
y_pred=regressor.predict(x_test)
df_results = pd.DataFrame({
    'X_test': x_test.flatten(),
    'Actual_Y': y_test.flatten(),
    'Predicted_Y': y_pred.flatten()
})
print(df_results.head(10))

# %%
from matplotlib import pyplot as plt
plt.plot(x_train,regressor.predict(x_train), color='red')
plt.scatter(X,y)
plt.title('Tv vs Sales')
plt.xlabel("TV")
plt.ylabel('Sales ')
plt.show()

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print(f"MAE:{mae} ,\n MSE:{mse} ,\n RMSE:{rmse},\n R2:{r2}")
# Out:
# MAE:2.505418178966003 ,
#  MSE:10.18618193453022 ,
#  RMSE:3.191579849311344,
#  R2:0.6763151577939721

# %%
train_score_lr = regressor.score(x_train, y_train)
test_score_lr = regressor.score(x_test, y_test)

print("The train score for lr model is: ", train_score_lr)
print("The test score for lr model is: ",test_score_lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f18efe18cefb> in <cell line: 1>()
# ----> 1 train_score_lr = regressor.score(x_train, y_train)
#       2 test_score_lr = regressor.score(x_test, y_test)
#       3
#       4 print("The train score for lr model is: ", train_score_lr)
#       5 print("The test score for lr model is: ",test_score_lr)
#
# NameError: name 'regressor' is not defined

# %% [markdown]
# *   TV ads and sales scale proportionally
# *   At some point, TV ads won't affect sales, that's why the dots are closely gathered at the beginning and start to deviate from the line creating a Cone shape
#
# *   TV ads are not the only factor in the sales of a product
# *
